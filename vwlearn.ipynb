# %%
import pandas as pd

# %%
new_df = pd.DataFrame({'A': [1, 2], 'B': [3, 4]})

# %%
new_df
# Out:
#    A  B
# 0  1  3
# 1  2  4

# %%
map
# Out:
# {'A': 0, 'B': 1}

# %%
for a, b in map.items():
    print(a, b)
# Out:
# A 0
# B 1

# %%
for _, row in new_df.iterrows():
    print(row.iloc[1])
# Out:
# 3
# 4
